# %% [markdown]
# #Data Acquisition Case Study

# %% [markdown]
# ## Q1. Write Python code to create a new file named "sample_data.txt" in your documents folder and write the following content to it
#
# ICTAK
#
# Thejaswini,
#
# Technopark Rd,
#
# Technopark Campus,
#
# Thiruvananthapuram,
#
# Kerala 695581

# %%
import os

# Get the path to the user's Documents folder
documents_folder = os.path.join(os.path.expanduser("~"), "Documents")

# Create full file path
file_path = os.path.join(documents_folder, "sample_data.txt")

# Content to write
content = """ICTAK

Thejaswini,

Technopark Rd,

Technopark Campus,

Thiruvananthapuram,

Kerala 695581"""

# Write to the file
with open(file_path, "w") as file:
    file.write(content)

print(f"File created at: {file_path}")
# Out:
# File created at: C:\Users\Admin\Documents\sample_data.txt

# %% [markdown]
# ## Q2. Write Python code to read and print the contents in "sample_data.txt"

# %%
if os.path.exists(file_path):
    with open(file_path, "r") as file:
        content = file.read()
        print("📄 File content:\n")
        print(content)
else:
    print("❌ The file 'sample_data.txt' does not exist.")
# Out:
# 📄 File content:
#
# ICTAK
#
# Thejaswini,
#
# Technopark Rd,
#
# Technopark Campus,
#
# Thiruvananthapuram,
#
# Kerala 695581

# %% [markdown]
# ## Q3. Write Python code to check if "sample_data.txt" exists in documents folder

# %%
import os

# Get path to the Documents folder
documents_folder = os.path.join(os.path.expanduser("~"), "Documents")
file_path = os.path.join(documents_folder, "sample_data.txt")

# Check if the file exists
if os.path.exists(file_path):
    print("✅ 'sample_data.txt' exists in Documents folder.")
else:
    print("❌ 'sample_data.txt' does not exist in Documents folder.")
# Out:
# ✅ 'sample_data.txt' exists in Documents folder.

# %% [markdown]
# ## Q4: Save the following dataframe content to a CSV file (data.csv) in your downloads folder

# %%
import pandas as pd

data = {"Id": [1, 2, 3],
        "Name": ["Alice", "Bob", "Charlie"],
        "Subject": ["Science", "Maths", "History"]}
df = pd.DataFrame(data)

# %%
import pandas as pd
import os

# Your DataFrame
data = {
    "Id": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "Subject": ["Science", "Maths", "History"]
}
df = pd.DataFrame(data)

# Path to Downloads folder
downloads_folder = os.path.join(os.path.expanduser("~"), "Downloads")
file_path = os.path.join(downloads_folder, "data.csv")

# Save DataFrame to CSV
df.to_csv(file_path, index=False)

print(f"✅ File saved successfully to: {file_path}")
# Out:
# ✅ File saved successfully to: C:\Users\Admin\Downloads\data.csv

# %% [markdown]
# ## Q5: Save the above dataframe content to an Excel (data.xlsx, sheet name: Sheet1) file in your documents folder

# %%
import pandas as pd
import os

# DataFrame
data = {
    "Id": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "Subject": ["Science", "Maths", "History"]
}
df = pd.DataFrame(data)

# Path to Documents folder
documents_folder = os.path.join(os.path.expanduser("~"), "Documents")
file_path = os.path.join(documents_folder, "data.xlsx")

# Save DataFrame to Excel
df.to_excel(file_path, sheet_name="Sheet1", index=False)

print(f"✅ Excel file saved to: {file_path}")
# Out:
# ✅ Excel file saved to: C:\Users\Admin\Documents\data.xlsx

# %% [markdown]
# ## Q6. Write code to get the list of files in your Downloads folder and save it to a CSV file name "download_list.csv"

# %%
import os
import pandas as pd

# Get path to Downloads folder
downloads_folder = os.path.join(os.path.expanduser("~"), "Downloads")

# List all files (excluding folders)
file_list = [f for f in os.listdir(downloads_folder) if os.path.isfile(os.path.join(downloads_folder, f))]

# Create DataFrame
df = pd.DataFrame(file_list, columns=["Filename"])

# Path to save the CSV file
csv_path = os.path.join(downloads_folder, "download_list.csv")

# Save to CSV
df.to_csv(csv_path, index=False)

print(f"✅ File list saved to: {csv_path}")
# Out:
# ✅ File list saved to: C:\Users\Admin\Downloads\download_list.csv

# %% [markdown]
# ## Q7. Write Python code to save the contents of the given random_array variable as a numpy file

# %%
import numpy as np
random_array = np.random.rand(10, 10)

# %%
import numpy as np
import os

# Create the array
random_array = np.random.rand(10, 10)

# Path to Documents folder
documents_folder = os.path.join(os.path.expanduser("~"), "Documents")
file_path = os.path.join(documents_folder, "random_array.npy")

# Save the array
np.save(file_path, random_array)

print(f"✅ Array saved successfully to: {file_path}")
# Out:
# ✅ Array saved successfully to: C:\Users\Admin\Documents\random_array.npy

# %% [markdown]
# ## Q8. Write python code to save the contents of the above numpy file as text file named "random.txt" with a delimitter of ";" to Documents folder

# %%
import numpy as np
import os

# Path to Documents folder
documents_folder = os.path.join(os.path.expanduser("~"), "Documents")

# Load the existing .npy file
npy_path = os.path.join(documents_folder, "random_array.npy")
random_array = np.load(npy_path)

# Path to save the .txt file
txt_path = os.path.join(documents_folder, "random.txt")

# Save as text with ";" delimiter
np.savetxt(txt_path, random_array, delimiter=";", fmt="%.5f")

print(f"✅ Array saved as text to: {txt_path}")
# Out:
# ✅ Array saved as text to: C:\Users\Admin\Documents\random.txt

# %% [markdown]
# ## Download and analyze Bike Sharing Dataset (hour.csv) for UCI Irvin Repository (https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset) and answer the following questions

# %% [markdown]
# ## Q9. What is the size of the dataset? (Number of rows and columns)

# %%
import os
import urllib.request
import zipfile

# Step 1: Download the ZIP file
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip"
downloads = os.path.join(os.path.expanduser("~"), "Downloads")
zip_path = os.path.join(downloads, "Bike-Sharing-Dataset.zip")

urllib.request.urlretrieve(url, zip_path)
print(f"✅ ZIP file downloaded to: {zip_path}")

# Step 2: Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(downloads)
    print("✅ ZIP file extracted in Downloads folder")
# Out:
# ✅ ZIP file downloaded to: C:\Users\Admin\Downloads\Bike-Sharing-Dataset.zip
# ✅ ZIP file extracted in Downloads folder

# %%
# Step 3: Load the 'hour.csv' file
import pandas as pd

csv_path = os.path.join(downloads, "hour.csv")
df = pd.read_csv(r"C:\Users\Admin\Downloads\hour.csv")

# Preview the dataset
print("✅ Dataset Loaded:")
print(df.head())
# Out:
# ✅ Dataset Loaded:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#What is the size of the dataset? (Number of rows and columns)
df.shape
# Out:
# (17379, 17)

# %%
print(f"📊 Number of rows: {df.shape[0]}")
print(f"📊 Number of columns: {df.shape[1]}")
# Out:
# 📊 Number of rows: 17379
# 📊 Number of columns: 17

# %%
print("🧾 Column names:")
print(df.columns.tolist())
# Out:
# 🧾 Column names:
# ['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %% [markdown]
# ## Q10. What are the data types of each column?

# %%
print(df.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ## Q11. Are there any missing values in the dataset? If so, which columns have missing values and how many?

# %%
missing_values = df.isnull().sum()

# Filter only columns with missing values
missing_columns = missing_values[missing_values > 0]

if missing_columns.empty:
    print("✅ No missing values in the dataset.")
else:
    print("⚠️ Columns with missing values:\n")
    print(missing_columns)
# Out:
# ✅ No missing values in the dataset.

# %% [markdown]
# ## Q.12. For the windspeed column, calculate the mean, median, and standard deviation.

# %%
mean_ws = df["windspeed"].mean()
median_ws = df["windspeed"].median()
std_ws = df["windspeed"].std()

print(f"🌬️ Windspeed Statistics:")
print(f"Mean: {mean_ws:.4f}")
print(f"Median: {median_ws:.4f}")
print(f"Standard Deviation: {std_ws:.4f}")
# Out:
# 🌬️ Windspeed Statistics:
# Mean: 0.1901
# Median: 0.1940
# Standard Deviation: 0.1223

# %% [markdown]
# ## Q13. Identify any potential outliers in a numerical column of your choice. Explain your approach.

# %%
# Choose the column
col = "windspeed"

# Q1 and Q3
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)

# IQR
IQR = Q3 - Q1

# Bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Outliers
outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

print(f"🔍 Outlier Detection in '{col}' column:")
print(f"Q1: {Q1:.4f}, Q3: {Q3:.4f}, IQR: {IQR:.4f}")
print(f"Lower Bound: {lower_bound:.4f}, Upper Bound: {upper_bound:.4f}")
print(f"Number of outliers: {outliers.shape[0]}")
# Out:
# 🔍 Outlier Detection in 'windspeed' column:
# Q1: 0.1045, Q3: 0.2537, IQR: 0.1492
# Lower Bound: -0.1193, Upper Bound: 0.4775
# Number of outliers: 342

# %% [markdown]
# ## Q.14 Find the correlation between numerical columns and discuss any interesting relationships.

# %%
# Compute correlation matrix of all numerical columns
correlation_matrix = df.corr(numeric_only=True)
print(correlation_matrix)
# Out:
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# weathersit -0.014198 -0.014524 -0.019157  0.005400 -0.020203 -0.017036
# temp        0.136178  0.312025  0.040913  0.201691  0.137603 -0.027340
# atemp       0.137615  0.319380  0.039222  0.208096  0.133750 -0.030973
# hum         0.009577  0.150625 -0.083546  0.164411 -0.276498 -0.010588
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Q.15 Based on your analysis, provide a brief summary of any insights or patterns you discovered in the dataset.

# %%
#Based on the analysis of the hour.csv dataset:

#1.Dataset Quality

#a)The dataset contains 17,379 rows and 17 columns.

#b)No missing values were found — it is clean and ready for analysis.

#2.User Behavior

#a)Registered users account for the majority of total rentals.

#b)Casual users tend to ride more on weekends and holidays, while registered users dominate during weekday peak hours (especially around 8 AM and 5–6 PM).

#3.Weather Influence

#a)Temperature and “feels like” temperature (atemp) have a positive correlation with bike usage — warmer weather increases rentals.

#b)Windspeed and humidity have a negative correlation with rentals — indicating that bad weather reduces demand.

#4.Correlations

#A)cnt (total rentals) is:

#a)Highly correlated with registered users (+0.97)

#b)Moderately correlated with casual users (+0.53)

#c)Positively correlated with temp (+0.40)

#d)Negatively correlated with windspeed and humidity

#5)Outliers

#a)Some high windspeed values were identified as outliers using the IQR method.

# %% [markdown]
# ## Q.16 In which season (Spring, Summer, Fall, Winter) people rented bikes the most?

# %%
# Step 1: Map numeric season codes to names
season_map = {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"}
df["season_name"] = df["season"].map(season_map)

# Step 2: Group by season and sum total rentals (cnt)
season_totals = df.groupby("season_name")["cnt"].sum()

# Step 3: Find the season with the highest rentals
most_rented_season = season_totals.idxmax()
max_rentals = season_totals.max()

# Step 4: Print the result
print("📊 Total Rentals by Season:")
print(season_totals)
print(f"\n✅ The season with the highest rentals is: **{most_rented_season}** with {max_rentals} total rentals.")
# Out:
# 📊 Total Rentals by Season:
# season_name
# Fall      1061129
# Spring     471348
# Summer     918589
# Winter     841613
# Name: cnt, dtype: int64
#
# ✅ The season with the highest rentals is: **Fall** with 1061129 total rentals.

# %% [markdown]
# ## Q.17 What is the peak hour in which bike rents the most?

# %%
# Group by hour and sum total rentals
hourly_totals = df.groupby("hr")["cnt"].sum()

# Find the hour with maximum rentals
peak_hour = hourly_totals.idxmax()
max_rentals = hourly_totals.max()

# Display result
print("📊 Total Rentals by Hour of the Day:")
print(hourly_totals)

print(f"\n✅ The peak hour with the highest bike rentals is: {peak_hour}:00 with {max_rentals} total rentals.")
# Out:
# 📊 Total Rentals by Hour of the Day:
# hr
# 0      39130
# 1      24164
# 2      16352
# 3       8174
# 4       4428
# 5      14261
# 6      55132
# 7     154171
# 8     261001
# 9     159438
# 10    126257
# 11    151320
# 12    184414
# 13    184919
# 14    175652
# 15    183149
# 16    227748
# 17    336860
# 18    309772
# 19    226789
# 20    164550
# 21    125445
# 22     95612
# 23     63941
# Name: cnt, dtype: int64
#
# ✅ The peak hour with the highest bike rentals is: 17:00 with 336860 total rentals.

# %% [markdown]
# ## Q.18 In which day of a week bikes rents out most?

# %%
# Map weekday numbers to names
weekday_map = {
    0: "Sunday", 1: "Monday", 2: "Tuesday", 3: "Wednesday",
    4: "Thursday", 5: "Friday", 6: "Saturday"
}
df["weekday_name"] = df["weekday"].map(weekday_map)

# Group by weekday and sum rentals
weekday_totals = df.groupby("weekday_name")["cnt"].sum()

# Sort and find peak day
peak_day = weekday_totals.idxmax()
max_rentals = weekday_totals.max()

# Display result
print("📅 Total Rentals by Day of Week:")
print(weekday_totals)

print(f"\n✅ The day with the highest rentals is: **{peak_day}** with {max_rentals} total rentals.")
# Out:
# 📅 Total Rentals by Day of Week:
# weekday_name
# Friday       487790
# Monday       455503
# Saturday     477807
# Sunday       444027
# Thursday     485395
# Tuesday      469109
# Wednesday    473048
# Name: cnt, dtype: int64
#
# ✅ The day with the highest rentals is: **Friday** with 487790 total rentals.

# %% [markdown]
# ## Q.19 In which hour Casual users rents bikes the most?

# %%
# Group by hour and sum casual rentals
casual_hourly = df.groupby("hr")["casual"].sum()

# Find the hour with the maximum casual rentals
peak_hour = casual_hourly.idxmax()
max_casual_rentals = casual_hourly.max()

# Display result
print("🚲 Casual User Rentals by Hour:")
print(casual_hourly)

print(f"\n✅ Casual users rent bikes the most at: {peak_hour}:00 with {max_casual_rentals} total rentals.")
# Out:
# 🚲 Casual User Rentals by Hour:
# hr
# 0      7375
# 1      4709
# 2      3412
# 3      1893
# 4       874
# 5      1012
# 6      3017
# 7      8037
# 8     15761
# 9     22458
# 10    33789
# 11    43286
# 12    49718
# 13    52713
# 14    55089
# 15    54606
# 16    53834
# 17    54220
# 18    44496
# 19    35505
# 20    26378
# 21    20570
# 22    16200
# 23    11065
# Name: casual, dtype: int64
#
# ✅ Casual users rent bikes the most at: 14:00 with 55089 total rentals.

# %% [markdown]
# ## Q.20 What is the maximum temperature observed in each of the seasons?

# %%
# Map season codes to names
season_map = {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"}
df["season_name"] = df["season"].map(season_map)

# Group by season and find the maximum temperature
max_temp_by_season = df.groupby("season_name")["temp"].max()

# Display results
print("🌡️ Maximum Temperature in Each Season (Normalized):")
print(max_temp_by_season)
# Out:
# 🌡️ Maximum Temperature in Each Season (Normalized):
# season_name
# Fall      1.00
# Spring    0.72
# Summer    0.94
# Winter    0.76
# Name: temp, dtype: float64
