# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\car_age_price (1).csv')

# %%
df.isnull().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
x = df[['Year']]  # Independent variable
y = df['Price']   # Dependent variable

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
intercept = model.intercept_
slope = model.coef_[0]
print(f"Price = {intercept:.2f} + {slope:.2f} * Year")
# Out:
# Price = -87147246.05 + 43453.38 * Year

# %%
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, model.predict(x), color='red', label='Linear Fit')
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Best Linear Fit: Year vs Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
predicted_price_2022 = model.predict([[2022]])
print("Predicted Price for 2022 model:", predicted_price_2022[0])
# Out:
# Predicted Price for 2022 model: 715488.0785097629
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
